# %%
import numpy as np
import jax.numpy as jnp
import time
import pandas as pd
import timeit
import distopia
from functools import partial

# %%
def dist_numpy(a, b, box):
    x = a - b
    return np.linalg.norm(x - np.rint(x / box) * box, axis=1)

# %%
from jax import jit

@jit
def dist_jax(a, b, box):
    x = a - b
    return jnp.linalg.norm(x - jnp.rint(x / box) * box, axis=1)

# %%
def dist_distopia(a, b, box):
    return distopia.distances_ortho(a, b, box)

# %% [markdown]
# # test with N = 1000

# %%
N = 10
box = 10
c0 = np.random.rand(N, 3).astype(np.float32)*2*box
c1 = np.random.rand(N, 3).astype(np.float32)*2*box
box = np.asarray([box, box, box], dtype=np.float32)

# %%
distances_distopia = dist_distopia(c0, c1, box)

# %%
distances_jax = dist_jax(c0, c1, box)

# %%
distances_numpy = dist_numpy(c0, c1, box)

# %%
np.testing.assert_array_almost_equal(distances_distopia, distances_jax)

# %%
np.testing.assert_array_almost_equal(distances_jax, distances_numpy)

# %%
def benchmark_jax(sizes, repeat=3, number=100, dtype=np.float32):
    results = []
    for size in sizes:
        print("running on size ", size)
        box = 10
        c0 = np.random.rand(size, 3).astype(np.float32)*2*box
        c1 = np.random.rand(size, 3).astype(np.float32)*2*box
        box = np.asarray([box, box, box], dtype=np.float32)

        c0 = jnp.array(c0)
        c1 = jnp.array(c1)
        box = jnp.array(box)

        # warmup the GPU 3 rounds
        r1 = dist_jax(c0, c1, box).block_until_ready()
        r2 = dist_jax(c0, c1, box).block_until_ready()
        r3 = dist_jax(c0, c1, box).block_until_ready()
        
        timer = timeit.Timer(lambda: dist_jax(c0, c1, box).block_until_ready())
        times = timer.repeat(repeat=repeat, number=number)

        
        results.append({
            'size': size,
            'mean': np.mean(times),
            'std_dev': np.std(times),
            'min': np.min(times),
            'max': np.max(times)
        })
    
    return pd.DataFrame(results)

# %%
def benchmark_numpy(sizes, repeat=3, number=100, dtype=np.float32):
    results = []
    for size in sizes:
        print("running on size ", size)
        box = 10
        c0 = np.random.rand(size, 3).astype(np.float32)*2*box
        c1 = np.random.rand(size, 3).astype(np.float32)*2*box
        box = np.asarray([box, box, box], dtype=np.float32)

        
        timer = timeit.Timer(lambda: dist_numpy(c0, c1, box))
        times = timer.repeat(repeat=repeat, number=number)

        results.append({
            'size': size,
            'mean': np.mean(times),
            'std_dev': np.std(times),
            'min': np.min(times),
            'max': np.max(times)
        })
    
    return pd.DataFrame(results)

# %%
def benchmark_distopia(sizes, repeat=3, number=100, dtype=np.float32):
    results = []
    for size in sizes:
        print("running on size ", size)
        box = 10
        c0 = np.random.rand(size, 3).astype(np.float32)*2*box
        c1 = np.random.rand(size, 3).astype(np.float32)*2*box
        box = np.asarray([box, box, box], dtype=np.float32)

        
        timer = timeit.Timer(lambda: distopia.distances_ortho(c0, c1, box))
        times = timer.repeat(repeat=repeat, number=number)
        
        results.append({
            'size': size,
            'mean': np.mean(times),
            'std_dev': np.std(times),
            'min': np.min(times),
            'max': np.max(times)
        })
    
    return pd.DataFrame(results)

# %%
sizes = np.logspace(1, 8, num=8, dtype=int)
print(sizes)
# Out:
# [       10       100      1000     10000    100000   1000000  10000000
#  100000000]

# %%
benchmark_results_jax = benchmark_jax(sizes)
benchmark_results_jax
# Out:
# running on size  10
# running on size  100
# running on size  1000
# running on size  10000
# running on size  100000
# running on size  1000000
# running on size  10000000
# running on size  100000000
#         size      mean   std_dev       min       max
# 0         10  0.002203  0.000735  0.001676  0.003242
# 1        100  0.001736  0.000024  0.001705  0.001762
# 2       1000  0.001815  0.000188  0.001667  0.002080
# 3      10000  0.002114  0.000300  0.001698  0.002393
# 4     100000  0.001853  0.000118  0.001758  0.002019
# 5    1000000  0.002399  0.000021  0.002375  0.002426
# 6   10000000  0.033256  0.000219  0.032987  0.033523
# 7  100000000  0.311737  0.000950  0.310406  0.312563

# %%
benchmark_results_numpy = benchmark_numpy(sizes)
benchmark_results_numpy
# Out:
# running on size  10
# running on size  100
# running on size  1000
# running on size  10000
# running on size  100000
# running on size  1000000
# running on size  10000000
# running on size  100000000
#         size        mean   std_dev         min         max
# 0         10    0.000402  0.000018    0.000387    0.000427
# 1        100    0.000558  0.000005    0.000551    0.000564
# 2       1000    0.002049  0.000232    0.001758    0.002325
# 3      10000    0.013896  0.000155    0.013772    0.014114
# 4     100000    0.137756  0.000205    0.137518    0.138019
# 5    1000000    1.608409  0.009423    1.601277    1.621724
# 6   10000000   19.777639  0.206011   19.599879   20.066424
# 7  100000000  192.560480  1.281922  191.254465  194.302400

# %%
benchmark_results_distopia = benchmark_distopia(sizes)
benchmark_results_distopia
# Out:
# running on size  10
# running on size  100
# running on size  1000
# running on size  10000
# running on size  100000
# running on size  1000000
# running on size  10000000
# running on size  100000000
#         size       mean   std_dev        min        max
# 0         10   0.000240  0.000013   0.000228   0.000257
# 1        100   0.000245  0.000004   0.000241   0.000250
# 2       1000   0.000359  0.000043   0.000298   0.000393
# 3      10000   0.000613  0.000009   0.000601   0.000622
# 4     100000   0.004542  0.000049   0.004505   0.004611
# 5    1000000   0.053415  0.000992   0.052619   0.054814
# 6   10000000   1.389209  0.001265   1.387894   1.390918
# 7  100000000  13.527633  0.175710  13.335887  13.760386

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.loglog(benchmark_results_jax['size'], benchmark_results_jax['mean'], marker='o', label='Jax Mean Execution Time', color="blue")
plt.loglog(benchmark_results_distopia['size'], benchmark_results_distopia['mean'], marker='o', label='Distopia Mean Execution Time', color="orange")
plt.loglog(benchmark_results_numpy['size'], benchmark_results_numpy['mean'], marker='o', label='Numpy Mean Execution Time', color="green")

plt.fill_between(benchmark_results_jax['size'], 
                 benchmark_results_jax['min'], 
                 benchmark_results_jax['max'], 
                 color='blue', alpha=0.3, label='Min-Max Range')

plt.fill_between(benchmark_results_distopia['size'], 
                 benchmark_results_distopia['min'], 
                 benchmark_results_distopia['max'], 
                 color='orange', alpha=0.3, label='Min-Max Range')

plt.fill_between(benchmark_results_numpy['size'], 
                 benchmark_results_numpy['min'], 
                 benchmark_results_numpy['max'], 
                 color='green', alpha=0.3, label='Min-Max Range')

plt.xlabel('Array Size')
plt.ylabel('Execution Time (s)')
plt.title('JAX Distance Computation Benchmark')
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.savefig("log-distopia-comparison.png")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(benchmark_results_jax['size'], benchmark_results_jax['mean'], marker='o', label='Jax Mean Execution Time', color="blue")
plt.plot(benchmark_results_distopia['size'], benchmark_results_distopia['mean'], marker='o', label='Distopia Mean Execution Time', color="orange")
plt.plot(benchmark_results_numpy['size'], benchmark_results_numpy['mean'], marker='o', label='Numpy Mean Execution Time', color="green")

plt.fill_between(benchmark_results_jax['size'], 
                 benchmark_results_jax['min'], 
                 benchmark_results_jax['max'], 
                 color='blue', alpha=0.3, label='Min-Max Range')

plt.fill_between(benchmark_results_distopia['size'], 
                 benchmark_results_distopia['min'], 
                 benchmark_results_distopia['max'], 
                 color='orange', alpha=0.3, label='Min-Max Range')

plt.fill_between(benchmark_results_numpy['size'], 
                 benchmark_results_numpy['min'], 
                 benchmark_results_numpy['max'], 
                 color='green', alpha=0.3, label='Min-Max Range')

plt.xlabel('Array Size')
plt.ylabel('Execution Time (s)')
plt.title('JAX Distance Computation Benchmark')
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()
